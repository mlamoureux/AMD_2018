# %% [markdown]
# # WaveSolver - 1D
# M. Lamoureux May 31, 2016. Pacific Insitute for the Mathematical Sciences. Updated June 15, 2016.
#
# ## Demo notes.
# Run "All Cells" then look at the last graph at the bottom. The slides will control various numerical solutions to the wave equation. So if you don't want to read all the section, you can just see the end results at the bottom.
#
# You can also examine each section individual, if you want to understand the numeric behind solving the one-dimensional wave equation (with constant coefficients). Becuase of a quirk in Boken, you have to run the cell with the plot, followed by the cell with the slider, in order to get each plot to work individually.
#
# This was also written as a test of how far we can push Bokeh and the Jupyter Hub in making some calculations and graphics.
#
# ## Math notes
# We have three examples of a numerical solver for the one dimensional wave equation:
# - explicit finite difference
# - implicit finite difference
# - D'Alembert's exact solution.
#
# In the demo, we show solutions for an initial position of  a triangular bump, then for an initial particle velocity of a triangular bump, and finally we compare the exact solution (d'Alembert) to the finite difference code. For fun, we also show how a moving Gaussian propagates.

# %% [markdown]
# ## Introduction to the 1D wave equation.
#
# The basic idea is to represent the vibrations of a (horizonal) string under tension by a function $u(x,t)$ where $x$ is the horizontal displacement along the string, $t$ is the time parameter, and $y=u(x,t)$ indicates the (vertical) displacement of the string at point $x$ along the string, at time $t$
#
# A typical wave would look something like
# $$u(x,t) = \sin(x-ct)$$
# which represents a sinusoidal wave moving to the right at velocity $c$.
#
# From Newon's law of motion (mass times acceleration equals force), we can derive the wave equation for the string in the form
# $$ \rho \cdot u_{tt} = k \cdot u_{xx}$$
# where $\rho$ is a mass density, $u_{tt}$ is an acceleration (the second derivative w.r.t. time), $k$ is the modulus of elasticity and $u_{xx}$ is a measure of curvature (the second derivative w.r.t. $x$), causing the bending force.
#
# Including boundary and initial conditions, while setting the parameter $c^2 = k/\rho$, we obtain the usual 1D wave equation on an interval as this:
#
#
# $$u_{tt} = c^2 u_{xx} \mbox{ on interval } [x_0,x_1]$$
# subject to boundary conditions
# $$u(x_0,t) = u(x_1, t) = 0 \mbox{ for all $t$. }$$
# and initial conditions
# $$u(x,0) = u_0(x), \quad u_t(x,t) = u_1(x) \mbox{ on interval } [x_0,x_1].$$
#
#
# Let's write some PDE solvers for this 1D wave equation.
#
# Start with some simple solvers, then get more complex.
#
# The function to solve the PDE needs to know $c^2, u_0, u_1$, the sampling intervals $dx$ and $dt$, and the number of time steps to execute. Everything else can be inferred from those inputs. The output should be a 2D array, indexed in x and t steps.
#
# Maybe we could actually output the solution $u(x,t)$ as well as the vector of indices for $x$ and $t$.

# %% [markdown]
# ## Software tools
# We import some tools for numerical work (NumPy, SciPy), plotting (Boken), and an interactive widget. We are using Boken because it is faster than matplotlib. Note, however, that Boken seems to be heavy on memory usage.
#
# You can read about the interactive widgets here: http://bokeh.pydata.org/en/0.10.0/_images/notebook_interactors.png

# %%
import numpy as np
from scipy.linalg import solve_toeplitz  # a matrix equation solver
from scipy.integrate import cumtrapz # a numerical integrator, using trapezoid rule
from bokeh.models import ColumnDataSource
from bokeh.plotting import *
from bokeh.io import push_notebook
from ipywidgets import interact, IntSlider

# %% [markdown]
# We need to initialize the Bokeh plotting methods with the following.

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="723f2433-13c5-4000-9ff8-267d2935937f">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Explicit method of solution in finite differences
#
# The finite difference method is probably the most common numerical method for solving PDEs. The derivatives are approximated by Newton difference ratios, and you step through in time to progress the solution from $t=0$ to some ending time.
#
# The following defines a function that solves the wave equation, using an explicit finite difference method. We follow the notes in the referenced book by Myint-U and Debnath.
#
# The differencing in spatial variable $x$ is done by a convolution, as this will be fast.
#
# We print out the value of the CFL constant as a sanity check. The method is stable and convergent provided the CFL value is less than one. (This means $dt$ needs to be small enough.) See the book for details.
#
# The input parameters are velocity squared $c2$, spatial step size $dx$, temporal step size $dt$, number of time steps $t$_$len$, initial position $u0$ and initial velocity $u1$. $u0$ and $u1$ are arrays of some length $N$, which the code will use to deduce everything it needs to know.
#
# I tend to think of these as dimensionless variables, but you can use real physical values if you like, so long as you are consistent. For instance $dx$ in meters, $dt$ in seconds, and $c2$ in (meters/second) squared.

# %%
# Based on Section 14.4 in Myint-U and Debnath's book
def w_solve1(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    for j in range(2,t_len):
        u[:,j] = np.convolve(u[:,j-1],kern)[1:x_len+1] - u[:,j-2] # eqn 14.4.3
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %% [markdown]
# ### First example
# We do 1000 steps in time and space, using a triangular waveform for the initial values. We then call the wave equation solver. Finally, we set up Bokeh to plot the answers for us.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# Here we solve the wave equation, with initial position $u(x,0)$ set to the triangle waveform
(u_exp,x,t)=w_solve1(c2,dx,dt,t_len,triangle,0*triangle)

# And now we plot the result, using Bokeh as our plotting method

y=u_exp[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="FD Explicit method solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,name="foo")

def update_exp(k=0):
    src.data['y']=u_exp[:,k]
    p.title='FD Explicit method solution"
    push_notebook()

show(p)
# Out:
# CFL value is  0.707106781187
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="61b0638e-40d3-40ee-8768-5008ec13a86a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("61b0638e-40d3-40ee-8768-5008ec13a86a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("61b0638e-40d3-40ee-8768-5008ec13a86a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '61b0638e-40d3-40ee-8768-5008ec13a86a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"39bece42-96b0-445e-b3b6-78636e497fa8":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"46eb11cd-4cfe-4b55-a0bf-1a76844fbb49","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"26a71a7a-b2b6-4dac-bb0d-9ca943247cce","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"0eb7ae6c-cbfa-423d-a5f1-602a8c93634e","subtype":"Figure","type":"Plot"},"ticker":{"id":"4955a426-e2d9-4389-9a7d-edb482518a95","type":"BasicTicker"}},"id":"3f2bce36-7252-4c97-880f-08121de23e6f","type":"Grid"},{"attributes":{},"id":"4955a426-e2d9-4389-9a7d-edb482518a95","type":"BasicTicker"},{"attributes":{"formatter":{"id":"604bd85c-6fc1-40dd-8f97-40ff2915f4c4","type":"BasicTickFormatter"},"plot":{"id":"0eb7ae6c-cbfa-423d-a5f1-602a8c93634e","subtype":"Figure","type":"Plot"},"ticker":{"id":"4955a426-e2d9-4389-9a7d-edb482518a95","type":"BasicTicker"}},"id":"22772369-b39e-479c-a627-babaf080c805","type":"LinearAxis"},{"attributes":{"formatter":{"id":"d67d00df-6791-4d49-a177-c9791a029349","type":"BasicTickFormatter"},"plot":{"id":"0eb7ae6c-cbfa-423d-a5f1-602a8c93634e","subtype":"Figure","type":"Plot"},"ticker":{"id":"95fb7517-daf5-4267-bacd-0d7e80259bc6","type":"BasicTicker"}},"id":"a5ca202f-91de-470e-8e44-910c1213971f","type":"LinearAxis"},{"attributes":{},"id":"95fb7517-daf5-4267-bacd-0d7e80259bc6","type":"BasicTicker"},{"attributes":{"plot":{"id":"0eb7ae6c-cbfa-423d-a5f1-602a8c93634e","subtype":"Figure","type":"Plot"}},"id":"9c716ab5-335a-4f9a-b22a-5ae5355acfcc","type":"PanTool"},{"attributes":{"callback":null},"id":"71e0e61c-df71-48cc-9bda-b6cfe545970f","type":"DataRange1d"},{"attributes":{"overlay":{"id":"529008c3-a8f7-46b5-9353-3e1eee6ec949","type":"BoxAnnotation"},"plot":{"id":"0eb7ae6c-cbfa-423d-a5f1-602a8c93634e","subtype":"Figure","type":"Plot"}},"id":"40bdceb5-9f58-4a26-85f8-de6827cdf07a","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"46eb11cd-4cfe-4b55-a0bf-1a76844fbb49","type":"ColumnDataSource"},"glyph":{"id":"26a71a7a-b2b6-4dac-bb0d-9ca943247cce","type":"Line"},"hover_glyph":null,"muted_glyph":null,"name":"foo","nonselection_glyph":{"id":"2df16155-3252-46b5-aed0-bc60de23a8c7","type":"Line"},"selection_glyph":null},"id":"3ca115f8-9ea5-4d8b-8bb3-0ff8b47b4d6f","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"4f57c242-22d8-420f-9b09-5728fe2e02ba","type":"DataRange1d"},{"attributes":{"plot":{"id":"0eb7ae6c-cbfa-423d-a5f1-602a8c93634e","subtype":"Figure","type":"Plot"},"ticker":{"id":"95fb7517-daf5-4267-bacd-0d7e80259bc6","type":"BasicTicker"}},"id":"8acad529-28db-461e-9624-2babd891198e","type":"Grid"},{"attributes":{},"id":"604bd85c-6fc1-40dd-8f97-40ff2915f4c4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0eb7ae6c-cbfa-423d-a5f1-602a8c93634e","subtype":"Figure","type":"Plot"}},"id":"48c58f1a-d365-4e29-ae07-b3269c93c6da","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"0eb7ae6c-cbfa-423d-a5f1-602a8c93634e","subtype":"Figure","type":"Plot"}},"id":"25a2d5f1-75a7-4c32-90a3-1f77772dbfb9","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"529008c3-a8f7-46b5-9353-3e1eee6ec949","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"0eb7ae6c-cbfa-423d-a5f1-602a8c93634e","subtype":"Figure","type":"Plot"}},"id":"e30382e5-da69-4da7-878b-ee29d1b1ea49","type":"ResetTool"},{"attributes":{},"id":"d67d00df-6791-4d49-a177-c9791a029349","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"FD Explicit method solution"},"id":"39f1f18d-4f4b-4efc-97e4-25cd3de8a ...

# %%
# We have to call up the slider in a separate cell
interact(update_exp,k=(0,t_len-1))
# Out:
# <function __main__.update_exp>

# %% [markdown]
# ### Second example
# As above, but we use the triangular waveform for the initial particle velocities. We take 3000 time steps, because the veolocity initial condition is a bit unusual, and we want to really see what is going on.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# We solve, but this time with the velocity $u_t$ initial condition equal to the triangle impulse. 3000 steps!
(u_expD,x,t)=w_solve1(.5,dx,dt,3*t_len,0*triangle,1*triangle)

# And now we plot the result, using Bokeh as our plotting method

y=u_expD[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="F.D. Explicit method, init velocity", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_expD(k=0):
    src.data['y']=u_expD[:,k]
    p.title="FD Explicit method, init velocity"
    push_notebook()

show(p)
# Out:
# CFL value is  0.707106781187
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4ae82969-2282-4ed3-8a34-5915d0d5c731"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4ae82969-2282-4ed3-8a34-5915d0d5c731");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4ae82969-2282-4ed3-8a34-5915d0d5c731");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4ae82969-2282-4ed3-8a34-5915d0d5c731' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"19c37db2-b1ef-4e9a-b91c-73c3ca8148e5":{"roots":{"references":[{"attributes":{"callback":null},"id":"d138ac86-fa82-4c10-8a80-ff20bf21e470","type":"DataRange1d"},{"attributes":{"plot":null,"text":"F.D. Explicit method, init velocity"},"id":"9361c13f-b902-4219-a09d-785e121a11c7","type":"Title"},{"attributes":{},"id":"2cb8e7b1-677b-4602-96c9-13a839ad53c7","type":"ToolEvents"},{"attributes":{},"id":"5c5da6bd-225d-443c-b2b9-01a773572e31","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1c64a2a-7ac4-45b3-953c-78fa9dbcce9f","type":"Line"},{"attributes":{"below":[{"id":"886b20d6-1a20-4278-b534-366a4abbec47","type":"LinearAxis"}],"left":[{"id":"bf401c75-5454-4c04-ad7e-f5be3d844802","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"886b20d6-1a20-4278-b534-366a4abbec47","type":"LinearAxis"},{"id":"723d37c1-35da-479a-a1c0-9d3f43873b4c","type":"Grid"},{"id":"bf401c75-5454-4c04-ad7e-f5be3d844802","type":"LinearAxis"},{"id":"d31ac83d-150f-40ea-95d8-d3822e3fedf1","type":"Grid"},{"id":"cc557101-cc4d-47bf-ad5d-53fd0a54c525","type":"BoxAnnotation"},{"id":"1e79e609-456d-4598-bc5f-beef1b38b8bc","type":"GlyphRenderer"}],"title":{"id":"9361c13f-b902-4219-a09d-785e121a11c7","type":"Title"},"tool_events":{"id":"2cb8e7b1-677b-4602-96c9-13a839ad53c7","type":"ToolEvents"},"toolbar":{"id":"8a2c45c2-34ce-45fb-927b-d32ecf7f2804","type":"Toolbar"},"x_range":{"id":"d138ac86-fa82-4c10-8a80-ff20bf21e470","type":"DataRange1d"},"y_range":{"id":"7db5c4c6-20d4-4498-8312-2f69cd0187d9","type":"DataRange1d"}},"id":"5caac532-e1c5-4ce2-929c-110746b36abc","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f33f69bd-2726-4052-a998-50b47264c7b6","type":"PanTool"},{"id":"d947d5b9-df60-47ce-8cf7-03e039096513","type":"WheelZoomTool"},{"id":"28ebbdf5-7439-43bc-95b7-b3b9c7fa531c","type":"BoxZoomTool"},{"id":"553bad77-62e9-4f43-8003-5cd26b9583e6","type":"SaveTool"},{"id":"1bf5e6dd-11ca-4903-aa0b-ea8fa73b056f","type":"ResetTool"},{"id":"69a5e498-7ed6-4f0c-b9d4-54bf129b5bc2","type":"HelpTool"}]},"id":"8a2c45c2-34ce-45fb-927b-d32ecf7f2804","type":"Toolbar"},{"attributes":{"data_source":{"id":"ada84368-cf1f-409d-9588-338d43283fe8","type":"ColumnDataSource"},"glyph":{"id":"6377446c-77c3-4c40-bbb3-f95830eebf9b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"name":"foo","nonselection_glyph":{"id":"c1c64a2a-7ac4-45b3-953c-78fa9dbcce9f","type":"Line"},"selection_glyph":null},"id":"1e79e609-456d-4598-bc5f-beef1b38b8bc","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"2393dc25-c300-49da-bb30-fdf09525d304","type":"BasicTickFormatter"},"plot":{"id":"5caac532-e1c5-4ce2-929c-110746b36abc","subtype":"Figure","type":"Plot"},"ticker":{"id":"1e73adea-01c0-4e88-92aa-2c6f4377d2e5","type":"BasicTicker"}},"id":"886b20d6-1a20-4278-b534-366a4abbec47","type":"LinearAxis"},{"attributes":{"callback":null},"id":"7db5c4c6-20d4-4498-8312-2f69cd0187d9","type":"DataRange1d"},{"attributes":{},"id":"1e73adea-01c0-4e88-92aa-2c6f4377d2e5","type":"BasicTicker"},{"attributes":{"plot":{"id":"5caac532-e1c5-4ce2-929c-110746b36abc","subtype":"Figure","type":"Plot"},"ticker":{"id":"1e73adea-01c0-4e88-92aa-2c6f4377d2e5","type":"BasicTicker"}},"id":"723d37c1-35da-479a-a1c0-9d3f43873b4c","type":"Grid"},{"attributes":{"formatter":{"id":"5c5da6bd-225d-443c-b2b9-01a773572e31","type":"BasicTickFormatter"},"plot":{"id":"5caac532-e1c5-4ce2-929c-110746b36abc","subtype":"Figure","type":"Plot"},"ticker":{"id":"070ca5d6-ed2a-404d-8889-c1456bdf930e","type":"BasicTicker"}},"id":"bf401c75-5454-4c04-ad7e-f5be3d844802","type":"LinearAxis"},{"attributes":{},"id":"070ca5d6-ed2a-404d-8889-c1456bdf930e","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"5caac532-e1c5-4ce2-929c-110746b36abc","subtype":"Figure","type":"Plot"},"ticker":{"id":"070ca5d6-ed2a-404d-8889-c1456bdf930e"," ...

# %%
# We have to call up the slider in a separate cell
interact(update_expD,k=(0,3*t_len-1))
# Out:
# <function __main__.update_expD>

# %% [markdown]
# ## Implicit method
#
# Here we try an implicit method for solving the wave equation. Again from Myint-U and Debnath's book, in Section 14.5, part (B) on Hyperbolic equations.
#
# We need to use scipy libraries as we have to solve a system of linear equation. In fact the system is tridiagonal and Toepliz, so this should be fast. I see how to use Toepliz in scipy, but I don't know how to tell it that the system is only tridiagonal. It should be possible to speed this up.

# %%
# Based on Section 14.5 (B) in Myint-U and Debnath's book
def w_solve2(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    # Note the above is a cheat, we are using the explicit method to find u[:,1], Should do this implicitly
    kern2 = np.array([e2, -2*(1+e2), e2]) # the convolution kernel we need for implicit solver. It is different.
    toepk = np.zeros(x_len)  # this will hold the entries for the tridiagonal Toeplitz matrix
    toepk[0] = 2*(1+e2);
    toepk[1] = -e2
    for j in range(2,t_len):
        rhs = np.convolve(u[:,j-2],kern2)[1:x_len+1] + 4*u[:,j-1] # eqn 14.5.17
        u[:,j] = solve_toeplitz(toepk, rhs) # here is a linear system solver (hence an implicit method)
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %% [markdown]
# ### Third example
# We do 1000 steps in time and space, using a triangular waveform for the initial values. We then call the implicit wave equation solver, which is supposed to be better. Finally, we set up Bokeh to plot the answers for us.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# solve with the implicit method
(u_imp,x,t)=w_solve2(c2,dx,dt,t_len,1*triangle,0*triangle)

# And now we plot the result

y=u_imp[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="FD Implicit method solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_imp(k=0):
    src.data['y']=u_imp[:,k]
    p.title="FD Implicit method solution"
    push_notebook()

show(p)
# Out:
# CFL value is  0.707106781187
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="26d2cd2a-c0e7-4de1-9952-817c4da69b92"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("26d2cd2a-c0e7-4de1-9952-817c4da69b92");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("26d2cd2a-c0e7-4de1-9952-817c4da69b92");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '26d2cd2a-c0e7-4de1-9952-817c4da69b92' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0774bcce-54a3-419d-8997-cf3b16b7913f":{"roots":{"references":[{"attributes":{"formatter":{"id":"a9d5357f-9def-4a8e-9e57-964231e2d2dd","type":"BasicTickFormatter"},"plot":{"id":"a53e6301-6969-4724-a042-b3db0f4659bf","subtype":"Figure","type":"Plot"},"ticker":{"id":"1e1bc76f-a999-459d-a746-1b9da35b1247","type":"BasicTicker"}},"id":"e97e1696-3eac-409d-8a73-7967ffa3c753","type":"LinearAxis"},{"attributes":{"callback":null},"id":"83efe660-c54f-4407-8e79-6d8f50c1c870","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"48a66905-eb64-45fd-b99f-3feaa4574913","type":"BoxAnnotation"},{"attributes":{},"id":"a9d5357f-9def-4a8e-9e57-964231e2d2dd","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"1965685a-0933-4410-a75f-904db8081f22","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"a93b46ad-7d0c-485d-bbb3-2dac8e0db0cf","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"a53e6301-6969-4724-a042-b3db0f4659bf","subtype":"Figure","type":"Plot"}},"id":"78bc1a09-2aff-46bc-8990-77f207709857","type":"PanTool"},{"attributes":{"plot":{"id":"a53e6301-6969-4724-a042-b3db0f4659bf","subtype":"Figure","type":"Plot"}},"id":"0d04d2bb-011f-4e49-bb41-b4799db17fb2","type":"ResetTool"},{"attributes":{},"id":"c49b0254-7da0-4339-b265-0c626f7454bb","type":"BasicTicker"},{"attributes":{},"id":"b494c6a6-0f45-40dc-9878-7e9e48f5298e","type":"ToolEvents"},{"attributes":{"plot":null,"text":"FD Implicit method solution"},"id":"dd9578d9-3ac0-4f3a-a37b-762be7d49f4d","type":"Title"},{"attributes":{"overlay":{"id":"48a66905-eb64-45fd-b99f-3feaa4574913","type":"BoxAnnotation"},"plot":{"id":"a53e6301-6969-4724-a042-b3db0f4659bf","subtype":"Figure","type":"Plot"}},"id":"176ae237-6c43-4964-a9aa-ac8820385976","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"a53e6301-6969-4724-a042-b3db0f4659bf","subtype":"Figure","type":"Plot"}},"id":"208de930-7995-40db-b8e5-a45f29087aab","type":"HelpTool"},{"attributes":{"below":[{"id":"e97e1696-3eac-409d-8a73-7967ffa3c753","type":"LinearAxis"}],"left":[{"id":"313148b4-0441-45b7-87b7-1c142d7d5ac0","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"e97e1696-3eac-409d-8a73-7967ffa3c753","type":"LinearAxis"},{"id":"e769a756-c2ea-42f8-9be6-7358d4708d32","type":"Grid"},{"id":"313148b4-0441-45b7-87b7-1c142d7d5ac0","type":"LinearAxis"},{"id":"e9b76c64-889f-4087-bdbd-e737b2bd81bf","type":"Grid"},{"id":"48a66905-eb64-45fd-b99f-3feaa4574913","type":"BoxAnnotation"},{"id":"0b462e5d-2c98-42d2-9c72-3625d5ab4b82","type":"GlyphRenderer"}],"title":{"id":"dd9578d9-3ac0-4f3a-a37b-762be7d49f4d","type":"Title"},"tool_events":{"id":"b494c6a6-0f45-40dc-9878-7e9e48f5298e","type":"ToolEvents"},"toolbar":{"id":"b2214668-89b0-4258-932d-e4b6fe30a6ce","type":"Toolbar"},"x_range":{"id":"83efe660-c54f-4407-8e79-6d8f50c1c870","type":"DataRange1d"},"y_range":{"id":"c1323f44-a570-4cdc-9690-0185055c280a","type":"DataRange1d"}},"id":"a53e6301-6969-4724-a042-b3db0f4659bf","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"a53e6301-6969-4724-a042-b3db0f4659bf","subtype":"Figure","type":"Plot"}},"id":"b34d3ab0-b1a3-4951-8328-c7499a5e76f8","type":"SaveTool"},{"attributes":{"plot":{"id":"a53e6301-6969-4724-a042-b3db0f4659bf","subtype":"Figure","type":"Plot"}},"id":"763d22fa-9fba-4019-8f92-56de192edd28","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"5c9e2268-386b-4d02- ...

# %%
interact(update_imp,k=(0,t_len-1))
# Out:
# <function __main__.update_imp>

# %% [markdown]
# ### Fourth example
# Derivative initial condition. Using the implicit solver, we solve for the initial particle velocity as a triangular waveform.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# Solve using the implicit solver. We do 3000 time steps to see what is going on. 
(u_impD,x,t)=w_solve2(c2,dx,dt,3*t_len,0*triangle,1*triangle)

# And now we plot the result

y=u_impD[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="FD Implicit method, init velocity", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_impD(k=0):
    src.data['y']=u_impD[:,k]
    p.title="FD Implicit method, init velocity"
    push_notebook()

show(p)
# Out:
# CFL value is  0.707106781187
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6f0235da-bcb4-4eae-b07b-855949001658"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6f0235da-bcb4-4eae-b07b-855949001658");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6f0235da-bcb4-4eae-b07b-855949001658");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6f0235da-bcb4-4eae-b07b-855949001658' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5e81d407-f70b-41ef-b066-5dcdd92281c4":{"roots":{"references":[{"attributes":{"formatter":{"id":"44f6f66b-a9fd-4a33-b7f4-dbbe98a74fc9","type":"BasicTickFormatter"},"plot":{"id":"2df9aa19-dc47-44aa-ae25-37a0d1819a38","subtype":"Figure","type":"Plot"},"ticker":{"id":"5e7b2aff-d5f9-49c0-954f-484faa23d4f5","type":"BasicTicker"}},"id":"79c0a7a6-6053-41d4-987d-ab08bf1dc257","type":"LinearAxis"},{"attributes":{"plot":{"id":"2df9aa19-dc47-44aa-ae25-37a0d1819a38","subtype":"Figure","type":"Plot"}},"id":"83314bed-850b-491e-9c69-01088711b310","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ee969e81-9d81-469b-b2fe-8829fe6a1c0d","type":"PanTool"},{"id":"9dfed5f5-85cb-4d96-bc58-1823ac5163f0","type":"WheelZoomTool"},{"id":"4e381fd3-e59a-42a9-8a56-ba315aa5ca4c","type":"BoxZoomTool"},{"id":"0883fc84-ce67-4822-8801-65f3f44d4f50","type":"SaveTool"},{"id":"9b5ff569-f2f6-49b8-ab3d-0f2c9a9518da","type":"ResetTool"},{"id":"83314bed-850b-491e-9c69-01088711b310","type":"HelpTool"}]},"id":"99a7ef3c-d6d3-443f-a706-b1f11a7c39d6","type":"Toolbar"},{"attributes":{"plot":null,"text":"FD Implicit method, init velocity"},"id":"b34b76d6-99ea-4654-826b-1d53691a4e17","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"9c521f38-2e38-4b31-9c04-3bcde9743758","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"95246f97-bf81-4804-8327-56f86ab22b33","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"51af5730-0f57-4b40-802f-7dbd2c2d6615","type":"Line"},{"attributes":{"plot":{"id":"2df9aa19-dc47-44aa-ae25-37a0d1819a38","subtype":"Figure","type":"Plot"}},"id":"9dfed5f5-85cb-4d96-bc58-1823ac5163f0","type":"WheelZoomTool"},{"attributes":{},"id":"44f6f66b-a9fd-4a33-b7f4-dbbe98a74fc9","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"f1ae137f-8f42-4ea2-a0ce-07cecf64f401","type":"BoxAnnotation"},"plot":{"id":"2df9aa19-dc47-44aa-ae25-37a0d1819a38","subtype":"Figure","type":"Plot"}},"id":"4e381fd3-e59a-42a9-8a56-ba315aa5ca4c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"2df9aa19-dc47-44aa-ae25-37a0d1819a38","subtype":"Figure","type":"Plot"}},"id":"ee969e81-9d81-469b-b2fe-8829fe6a1c0d","type":"PanTool"},{"attributes":{"callback":null},"id":"91677c3a-430c-4187-b016-e4187142dc8d","type":"DataRange1d"},{"attributes":{"formatter":{"id":"9d8e912e-8e98-492b-b685-b75466f8ca62","type":"BasicTickFormatter"},"plot":{"id":"2df9aa19-dc47-44aa-ae25-37a0d1819a38","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f839cda-2970-4978-9b13-4fcef0f0fe32","type":"BasicTicker"}},"id":"231788cb-374e-4114-b2f1-e1d2ddbae9f5","type":"LinearAxis"},{"attributes":{"plot":{"id":"2df9aa19-dc47-44aa-ae25-37a0d1819a38","subtype":"Figure","type":"Plot"}},"id":"9b5ff569-f2f6-49b8-ab3d-0f2c9a9518da","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"2df9aa19-dc47-44aa-ae25-37a0d1819a38","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f839cda-2970-4978-9b13-4fcef0f0fe32","type":"BasicTicker"}},"id":"fa81bf00-a31b-4dcb-a826-4648098d04b0","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f1ae137f-8f42-4ea2-a0ce-07cecf64f401","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"9c521f38-2e38-4b31-9c04-3bcde9743758","type":"ColumnDataSource"},"glyph":{"id":"87389b08-790d-4b55-bb11-aa5922cdcf22","type":"Line"},"hover_glyph":null,"muted_glyph":null,"name":"foo","nonselection_glyph":{"id":"51af5730-0f57-4b40-802f-7dbd2c2d ...

# %%
interact(update_impD,k=(0,3*t_len-1))
# Out:
# <function __main__.update_impD>

# %% [markdown]
# ## D'Alembert's solution
#
# Since the velocity $c$ is constant in these examples, we can get the exact solution via D'Alembert. The general solution will be of the form
# $$u(x,t) = \phi(x+ct) + \psi(x-ct). $$
# Initial conditions tell use that
# $$u(x,0) = \phi(x) + \psi(x) = f(x), $$ and
# $$u_t(x,0) = c\phi'(x) - c\psi'(x) = g(x). $$
# With $G(x)$ the antiderivative of $g(x)$ with appropriate zero at zero, we get a 2x2 system
# $$\phi(x) + \psi(x) = f(x), \\ c(\phi(x) - \psi(x)) = G(x),$$
# which we solve as
# $$\phi(x) = \frac{1}{2}\left( f(x) + \frac{1}{c} G(x) \right), \\
#   \psi(x) = \frac{1}{2}\left( f(x) - \frac{1}{c} G(x) \right).$$
#
# Now $f(x)$ is given as the argument $u0$ in the code. $G(x)$ can be computed using scipy. The arguments $x+ct$ and $x-ct$ must be converted to integer indices. They have to wrap around. And with the zero boundary condition, we need to wrap around with a negative reflection.
#
# There is the messy question as to whether we require $u(0,t)$ to actually equal zero, or do we require it to be zero one index "to the left" of x=0. Let's not think too much about that just yet.

# %%
# Based on D'Alembert's solution, as described above
def w_solve3(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    c = np.sqrt(c2)  # the actual velocity parameter is needed
    f = u0  # use notation from above notes
    G = cumtrapz(u1,dx=dx,initial=0) # the antiderivative, using cumulative trapezoidal rule
    f2 = np.append(f,-f[::-1]) # odd symmetry
    G2 = np.append(G,G[::-1]) # even symmetry
    phi2 = (f2 + G2/c)/2
    psi2 = (f2 - G2/c)/2
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    # in the loop, we convert x+ct to index's into vectors phi2, psi2, modulo the vector length
    for j in range(t_len):
        ii1 = np.mod( np.round((x+c*t[j])/dx), 2*x_len)
        ii2 = np.mod( np.round((x-c*t[j])/dx), 2*x_len)
        u[:,j] = phi2[ii1.astype(int)] + psi2[ii2.astype(int)]
    return u,x,t

# %% [markdown]
# ### Fifth example
#
# We do 1000 steps in time and space, using a triangular waveform for the initial values.
# We then call the d'Alembert wave equation solver, which should be exact to machine precision.
# Finally, we set up Bokeh to plot the answers for us.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# solve using our d'Alembert solver
(u_dal,x,t)=w_solve3(c2,dx,dt,t_len,1*triangle,0*triangle)

# and now we plot

y=u_dal[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_dal(k=0):
    src.data['y']=u_dal[:,k]
    p.title="D'Alembert solution"
    push_notebook()

show(p)
# Out:
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="912f1bae-9d79-4cf8-87e1-98fb62847d70"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("912f1bae-9d79-4cf8-87e1-98fb62847d70");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("912f1bae-9d79-4cf8-87e1-98fb62847d70");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '912f1bae-9d79-4cf8-87e1-98fb62847d70' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"58774ad4-4f53-407e-b07c-55a2a136f940":{"roots":{"references":[{"attributes":{"below":[{"id":"2e803a98-d344-40b8-a218-2cb336484b95","type":"LinearAxis"}],"left":[{"id":"58c5a7f5-9ea6-462c-a9bf-24b81be1738e","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"2e803a98-d344-40b8-a218-2cb336484b95","type":"LinearAxis"},{"id":"6e6c4cdf-17de-4e68-89cc-5074b1c1d59f","type":"Grid"},{"id":"58c5a7f5-9ea6-462c-a9bf-24b81be1738e","type":"LinearAxis"},{"id":"de5e6e1d-45ed-4897-b253-d17023cb6141","type":"Grid"},{"id":"1514a451-6cce-41bf-988e-a5741b6a1a6a","type":"BoxAnnotation"},{"id":"f7e2891d-8ffe-4cd0-87e6-25d8f8335653","type":"GlyphRenderer"}],"title":{"id":"b643d301-c24a-401f-a3a0-983b302421f5","type":"Title"},"tool_events":{"id":"c520224b-312e-4c5c-9ee3-c12cb9f0d818","type":"ToolEvents"},"toolbar":{"id":"20b5e6b6-9f7e-4e3a-ad12-8163c65c5958","type":"Toolbar"},"x_range":{"id":"e118057c-f279-4404-809a-948bac77b617","type":"DataRange1d"},"y_range":{"id":"36041a93-813b-48a0-a0e1-28996af202d5","type":"DataRange1d"}},"id":"4478db8e-2f81-4d31-9660-4424cae77324","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"96f9b615-cd3c-42c3-b080-176559706ae7","type":"ColumnDataSource"},"glyph":{"id":"a81bca06-0e64-4c9c-96a9-4c33b9cfbc36","type":"Line"},"hover_glyph":null,"muted_glyph":null,"name":"foo","nonselection_glyph":{"id":"20fc54c2-94d8-463c-8faf-bd1484aa4ed6","type":"Line"},"selection_glyph":null},"id":"f7e2891d-8ffe-4cd0-87e6-25d8f8335653","type":"GlyphRenderer"},{"attributes":{},"id":"5c7d61a6-456d-47f0-b9ee-60838e49300a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4478db8e-2f81-4d31-9660-4424cae77324","subtype":"Figure","type":"Plot"}},"id":"f59ea9ec-5490-4113-94f9-1b4dacb8bdaf","type":"HelpTool"},{"attributes":{"plot":{"id":"4478db8e-2f81-4d31-9660-4424cae77324","subtype":"Figure","type":"Plot"},"ticker":{"id":"95711d12-19b0-4002-89d5-6ef3e7d30bcc","type":"BasicTicker"}},"id":"6e6c4cdf-17de-4e68-89cc-5074b1c1d59f","type":"Grid"},{"attributes":{},"id":"95711d12-19b0-4002-89d5-6ef3e7d30bcc","type":"BasicTicker"},{"attributes":{},"id":"887ce7d5-cccd-456d-8a38-35942c505dca","type":"BasicTicker"},{"attributes":{"formatter":{"id":"c6364860-eebe-4650-a97e-0af91ee99db4","type":"BasicTickFormatter"},"plot":{"id":"4478db8e-2f81-4d31-9660-4424cae77324","subtype":"Figure","type":"Plot"},"ticker":{"id":"887ce7d5-cccd-456d-8a38-35942c505dca","type":"BasicTicker"}},"id":"58c5a7f5-9ea6-462c-a9bf-24b81be1738e","type":"LinearAxis"},{"attributes":{"plot":{"id":"4478db8e-2f81-4d31-9660-4424cae77324","subtype":"Figure","type":"Plot"}},"id":"94d6b805-f179-4852-a64e-0f0131d8d607","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"4478db8e-2f81-4d31-9660-4424cae77324","subtype":"Figure","type":"Plot"},"ticker":{"id":"887ce7d5-cccd-456d-8a38-35942c505dca","type":"BasicTicker"}},"id":"de5e6e1d-45ed-4897-b253-d17023cb6141","type":"Grid"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"a81bca06-0e64-4c9c-96a9-4c33b9cfbc36","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"20fc54c2-94d8-463c-8faf-bd1484aa4ed6","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1514a451-6cce-41bf-988e-a5741b6a1a6a","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"96f9b615-cd3c-42c3-b080-176559706ae7","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"36041a93-81 ...

# %%
interact(update_dal,k=(0,t_len-1))
# Out:
# <function __main__.update_dal>

# %% [markdown]
# ### Sixth example
# Derivative initial condition. Using the exact solver, we solve for the initial particle velocity as a triangular waveform. Derivative initial condition.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# solve using our d'Alembert solver. We do 3000 time steps, to see what is going on.
(u_dalD,x,t)=w_solve3(c2,dx,dt,3*t_len,0*triangle,1*triangle)

# And now we plot the result

y=u_dalD[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert method, init velocity", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_dalD(k=0):
    src.data['y']=u_dalD[:,k]
    p.title="D'Alembert method, init velocity"
    push_notebook()

show(p)
# Out:
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="61e6f380-47fd-42f8-9271-7e4e1a2dff59"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("61e6f380-47fd-42f8-9271-7e4e1a2dff59");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("61e6f380-47fd-42f8-9271-7e4e1a2dff59");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '61e6f380-47fd-42f8-9271-7e4e1a2dff59' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8e0f76c0-65f8-47a8-9e7c-7a67c7bd434e":{"roots":{"references":[{"attributes":{"plot":{"id":"78c5b843-807d-4da5-8373-3656f89f4cd6","subtype":"Figure","type":"Plot"}},"id":"881b974b-c550-4878-8e0f-7a8acf0b65ed","type":"PanTool"},{"attributes":{"plot":{"id":"78c5b843-807d-4da5-8373-3656f89f4cd6","subtype":"Figure","type":"Plot"}},"id":"f5421921-5618-4847-8eb0-01345724dadf","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"afa612af-37eb-428b-b689-c7784dcea3c5","type":"BoxAnnotation"},"plot":{"id":"78c5b843-807d-4da5-8373-3656f89f4cd6","subtype":"Figure","type":"Plot"}},"id":"5adfb032-6ec9-427c-976f-51e9a7a48545","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"78c5b843-807d-4da5-8373-3656f89f4cd6","subtype":"Figure","type":"Plot"}},"id":"38e1786c-8fc4-400b-857e-a982e39f930d","type":"SaveTool"},{"attributes":{"plot":{"id":"78c5b843-807d-4da5-8373-3656f89f4cd6","subtype":"Figure","type":"Plot"}},"id":"37d58ffd-63df-407e-9ca8-6801072bb7eb","type":"ResetTool"},{"attributes":{"plot":{"id":"78c5b843-807d-4da5-8373-3656f89f4cd6","subtype":"Figure","type":"Plot"}},"id":"5a1134e1-2541-4a5d-88cd-c95a9fffb8b5","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"33fc0b9e-20f6-4d96-8581-651361da2155","type":"ColumnDataSource"},{"attributes":{},"id":"b32b0ebe-0518-497f-87a1-7a3b7ec99bc1","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"4562abb7-67c8-423b-bd71-7dc70f896bce","type":"DataRange1d"},{"attributes":{},"id":"a86f7d09-4b8c-4bfd-8f4c-276428d13b62","type":"ToolEvents"},{"attributes":{"plot":null,"text":"D'Alembert method, init velocity"},"id":"974260f2-5880-40d9-90e9-0ecf0a58ff1a","type":"Title"},{"attributes":{},"id":"304f3a3e-d8d3-4a56-aa9d-1241ecffec18","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"881b974b-c550-4878-8e0f-7a8acf0b65ed","type":"PanTool"},{"id":"f5421921-5618-4847-8eb0-01345724dadf","type":"WheelZoomTool"},{"id":"5adfb032-6ec9-427c-976f-51e9a7a48545","type":"BoxZoomTool"},{"id":"38e1786c-8fc4-400b-857e-a982e39f930d","type":"SaveTool"},{"id":"37d58ffd-63df-407e-9ca8-6801072bb7eb","type":"ResetTool"},{"id":"5a1134e1-2541-4a5d-88cd-c95a9fffb8b5","type":"HelpTool"}]},"id":"dff19d04-b670-43d1-9fa2-573947fa2478","type":"Toolbar"},{"attributes":{"data_source":{"id":"33fc0b9e-20f6-4d96-8581-651361da2155","type":"ColumnDataSource"},"glyph":{"id":"804fad58-dd5d-457a-9c1a-31b3013c65de","type":"Line"},"hover_glyph":null,"muted_glyph":null,"name":"foo","nonselection_glyph":{"id":"b9c3dc74-48b6-4eda-92a9-469500221693","type":"Line"},"selection_glyph":null},"id":"2d7d6b9f-9ab0-43a6-9ed5-d9936d23ca36","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"304f3a3e-d8d3-4a56-aa9d-1241ecffec18","type":"BasicTickFormatter"},"plot":{"id":"78c5b843-807d-4da5-8373-3656f89f4cd6","subtype":"Figure","type":"Plot"},"ticker":{"id":"b429f015-3eb1-4ee3-ba01-6c3405f31114","type":"BasicTicker"}},"id":"9cf295b3-abfd-48a2-b39e-2c1a08f52c33","type":"LinearAxis"},{"attributes":{"callback":null},"id":"2bf7240f-c13c-4818-a748-02c6ad4cd770","type":"DataRange1d"},{"attributes":{},"id":"b429f015-3eb1-4ee3-ba01-6c3405f31114","type":"BasicTicker"},{"attributes":{"plot":{"id":"78c5b843-807d-4da5-8373-3656f89f4cd6","subtype":"Figure","type":"Plot"},"ticker":{"id":"b429f015-3eb1-4ee3-ba01-6c3405f31114","type":"BasicTicker"}},"id":"61241f92-9148-4281-b564-f0df0594b764","type":"Grid"},{"attributes":{"formatter":{"id":"b32b0ebe-0518-497f-87a1-7a3b7ec99bc1","type":"BasicTickFormatter"},"plot":{"id":"78c5b843-807d-4da5-8373-3656f89f4cd6","subtype":"Figure","type":"Plot"},"ticker":{"id":"956b15a5-a50a-40cc-8bc0-d06041fa98e5","type":"BasicTicker"}},"id":"b72db75e-d3b7-4977-94d5-c9b65037a673","type":"LinearAxis"},{"attributes":{},"id":"956b15a5-a50a-40cc-8bc0-d06041fa98e5","typ ...

# %%
interact(update_dalD,k=(0,3*t_len-1))
# Out:
# <function __main__.update_dalD>

# %% [markdown]
# # Comparing solutions
#
# ### Seventh example
#
# In principle, we want these different solution methods to be directly comparable.
#
# So let's try this out, by computing the difference of two solution.
#
# Here we compare the explicit f.d. method with d'Alambert's method.

# %%
# If you want, you can re-compute these. But we did it above already.
#(u_exp,x,t)=w_solve1(.5,dx,dt,t_len,1*triangle,0*triangle)
#(u_dal,x,t)=w_solve3(.5,dx,dt,t_len,1*triangle,0*triangle)

y=u_dal[:,0]-u_exp[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert minus explicit", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_comp(k=0):
    src.data['y']=u_dal[:,k]-u_exp[:,k]
    p.title="D'Alembert minus explicit"
    push_notebook()
    
show(p)
# Out:
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bc67edb3-7ecf-44bf-89b1-aa09c8253648"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bc67edb3-7ecf-44bf-89b1-aa09c8253648");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bc67edb3-7ecf-44bf-89b1-aa09c8253648");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bc67edb3-7ecf-44bf-89b1-aa09c8253648' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"12930032-124b-48d1-8e91-b372726fb6bd":{"roots":{"references":[{"attributes":{},"id":"5ceeaaca-ea71-4293-b98b-c18bf5787d6e","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"0cb970ea-564d-410e-96d9-0df433a4af7c","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"fdcc2a2d-71a1-4682-be8d-b614d7b5f311","type":"Line"},{"attributes":{"below":[{"id":"26102d11-7f2b-4f53-bfed-99dc33b4e1e1","type":"LinearAxis"}],"left":[{"id":"97a4ebee-9481-4548-9653-ccd748a517a9","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"26102d11-7f2b-4f53-bfed-99dc33b4e1e1","type":"LinearAxis"},{"id":"1c86fd44-e4ba-4eb7-9ea7-3922a6df8803","type":"Grid"},{"id":"97a4ebee-9481-4548-9653-ccd748a517a9","type":"LinearAxis"},{"id":"aa91f5e9-edff-4770-8a7d-9d80b6bd7ed9","type":"Grid"},{"id":"9274ba5c-31ce-4f6f-9bbe-8ba2c47b77ef","type":"BoxAnnotation"},{"id":"a7d4cafb-7fff-48a7-ac74-af7e2275c494","type":"GlyphRenderer"}],"title":{"id":"94ef86ba-1005-410b-9340-9ed94febfced","type":"Title"},"tool_events":{"id":"ddac3e23-4c7e-4f67-b72e-01a08d6a2dad","type":"ToolEvents"},"toolbar":{"id":"15138ac3-267e-4a9f-99e9-ee1e2f476f61","type":"Toolbar"},"x_range":{"id":"3ac99a4f-e92e-4a5a-a9a7-92029f9707d3","type":"DataRange1d"},"y_range":{"id":"dd6111f3-7692-4d7e-a036-7b2440bc6aad","type":"DataRange1d"}},"id":"125e0b4e-de0b-4c90-855f-75680c3be954","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"d36930ff-d580-41b3-83f1-e5490e585eb5","type":"BasicTicker"},{"attributes":{"plot":{"id":"125e0b4e-de0b-4c90-855f-75680c3be954","subtype":"Figure","type":"Plot"}},"id":"3a1fe497-5fd1-4e95-a4a6-f5a3b02fa676","type":"HelpTool"},{"attributes":{"plot":null,"text":"D'Alembert minus explicit"},"id":"94ef86ba-1005-410b-9340-9ed94febfced","type":"Title"},{"attributes":{"callback":null},"id":"3ac99a4f-e92e-4a5a-a9a7-92029f9707d3","type":"DataRange1d"},{"attributes":{"plot":{"id":"125e0b4e-de0b-4c90-855f-75680c3be954","subtype":"Figure","type":"Plot"}},"id":"20ff5cc6-8e32-4c90-bae6-a706412e859c","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b24bce6c-cce9-4744-83b6-06f510877882","type":"PanTool"},{"id":"53c1efd3-c24b-44f8-902c-a01f77c39dec","type":"WheelZoomTool"},{"id":"25fa18da-7a7c-4171-a89a-46d97f369aa7","type":"BoxZoomTool"},{"id":"cde3f731-554f-4402-8648-0bbfaf7a045c","type":"SaveTool"},{"id":"20ff5cc6-8e32-4c90-bae6-a706412e859c","type":"ResetTool"},{"id":"3a1fe497-5fd1-4e95-a4a6-f5a3b02fa676","type":"HelpTool"}]},"id":"15138ac3-267e-4a9f-99e9-ee1e2f476f61","type":"Toolbar"},{"attributes":{},"id":"ddac3e23-4c7e-4f67-b72e-01a08d6a2dad","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"125e0b4e-de0b-4c90-855f-75680c3be954","subtype":"Figure","type":"Plot"},"ticker":{"id":"543320ec-f258-419d-823f-3dfd303006b0","type":"BasicTicker"}},"id":"aa91f5e9-edff-4770-8a7d-9d80b6bd7ed9","type":"Grid"},{"attributes":{"callback":null},"id":"dd6111f3-7692-4d7e-a036-7b2440bc6aad","type":"DataRange1d"},{"attributes":{},"id":"cba1e62f-880d-4b15-9d68-8038db74e388","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"5ceeaaca-ea71-4293-b98b-c18bf5787d6e","type":"BasicTickFormatter"},"plot":{"id":"125e0b4e-de0b-4c90-855f-75680c3be954","subtype":"Figure","type":"Plot"},"ticker":{"id":"543320ec-f258-419d-823f-3dfd303006b0","type":"BasicTicker"}},"id":"97a4ebee-9481-4548-9653-ccd748a517a9","type":"LinearAxis"},{"attributes":{"formatter":{"id":"cba1e62f-880d-4b15-9d68-8038db74e388","type":"BasicTickFormatter"},"plot":{"id":"125e0b4e-de0b-4c90-855f-75680c3be954","subtype":"Figure","type":"Plot"},"ticker":{"id":"d36930ff-d580-41b3-83f1-e5490e585eb5","type":"BasicTicker"}},"id":"26102d11-7f2b-4f5 ...

# %%
interact(update_comp,k=(0,t_len-1))
# Out:
# <function __main__.update_comp>

# %% [markdown]
# # A moving wavefront
#
# ### Example eight
#
# Let's try an actual wave. We want something like
# $$u(x,t) = \exp(-(x -x_a-ct)^2/w^2), $$
# where $x_a$ is the center of the Gaussian at $t=0$, $w$ is the width of the Gaussian, $c$ is the velocity of the wave.
#
# This gives
# $$u_0(x) = \exp(-(x -x_a)^2/w^2) \\
#   u_1(x) = \frac{2c(x-x_a)}{w^2}\exp(-(x -x_a)^2/w^2) = \frac{2c(x-x_a)}{w^2}u_0(x).$$

# %%
# We set up the initial waveform corresponding to a Gaussian moving to the right.
# The value of velocity c is very important here!
c = .707  # velocity
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
u0 = np.exp(-(x-.5)*(x-.5)/.01)
u1 = 2*c*u0*(x-.5)/.01

# now we solve using the d'Alembert solution. We do 3000 steps, though!

(u_wav,x,t)=w_solve3(c*c,dx,dt,3*t_len,u0,u1)  # notice we input the velocity squared!

# And now we plot

y=u_wav[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))
p = figure(title="Moving wave", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_wav(k=0):
    src.data['y']=u_wav[:,k]
    p.title="Moving wave"
    push_notebook()
    
show(p)
# Out:
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/mikel/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4d9f525c-2584-4a30-b9eb-45349e9677fe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4d9f525c-2584-4a30-b9eb-45349e9677fe");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4d9f525c-2584-4a30-b9eb-45349e9677fe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4d9f525c-2584-4a30-b9eb-45349e9677fe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2e87dbd6-b249-4896-911b-0878996f3c90":{"roots":{"references":[{"attributes":{"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"},"ticker":{"id":"dba42c0e-0a9f-4224-8b03-42f4b9622c9a","type":"BasicTicker"}},"id":"68c82762-f047-4929-9302-2d47ea86dcee","type":"Grid"},{"attributes":{"formatter":{"id":"fe06140b-74dc-48a2-a40a-dc015a428866","type":"BasicTickFormatter"},"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"},"ticker":{"id":"d188b7e7-4e67-41fd-bcae-397dfea85af9","type":"BasicTicker"}},"id":"051e69ec-7de6-47e5-b00a-8f63760684c9","type":"LinearAxis"},{"attributes":{"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"}},"id":"545911ad-145d-44fa-89d6-cd9dbf6c449c","type":"SaveTool"},{"attributes":{"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"}},"id":"fd0f2d0d-a7b9-4ea0-8ad9-ebaabef2bf77","type":"ResetTool"},{"attributes":{"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"}},"id":"67707b69-1a8e-47e6-b24d-0f8f827f1aea","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"},"ticker":{"id":"d188b7e7-4e67-41fd-bcae-397dfea85af9","type":"BasicTicker"}},"id":"e1efa689-6e7e-4adc-ba38-4d05b923523c","type":"Grid"},{"attributes":{"callback":null},"id":"520102f6-d35f-47a0-9be6-4f4d83c6f610","type":"DataRange1d"},{"attributes":{},"id":"fe06140b-74dc-48a2-a40a-dc015a428866","type":"BasicTickFormatter"},{"attributes":{},"id":"dba42c0e-0a9f-4224-8b03-42f4b9622c9a","type":"BasicTicker"},{"attributes":{"formatter":{"id":"0b03b6a6-b7f6-4298-b3d9-5fc3fb42243f","type":"BasicTickFormatter"},"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"},"ticker":{"id":"dba42c0e-0a9f-4224-8b03-42f4b9622c9a","type":"BasicTicker"}},"id":"572b9c96-155c-4bee-aa2e-8f42d1c3871a","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9606e122-cd89-4179-a745-158d0868a4ea","type":"PanTool"},{"id":"f3d91650-566e-4c44-8f36-edf22b9d851c","type":"WheelZoomTool"},{"id":"46a4d405-23b8-48fb-83a4-cfde1a3a374d","type":"BoxZoomTool"},{"id":"545911ad-145d-44fa-89d6-cd9dbf6c449c","type":"SaveTool"},{"id":"fd0f2d0d-a7b9-4ea0-8ad9-ebaabef2bf77","type":"ResetTool"},{"id":"67707b69-1a8e-47e6-b24d-0f8f827f1aea","type":"HelpTool"}]},"id":"4f8c7a4c-360b-467e-9282-dc4bc2b76c3f","type":"Toolbar"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7899b394-ffeb-4b5d-b0ff-ff0472ff33d9","type":"Line"},{"attributes":{},"id":"0b03b6a6-b7f6-4298-b3d9-5fc3fb42243f","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b48c53f7-fd91-4cf8-a599-505725a0cbfb","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"e38a120a-7809-42a1-96c3-2d19515ca94e","type":"ColumnDataSource"},"glyph":{"id":"7899b394-ffeb-4b5d-b0ff-ff0472ff33d9","type":"Line"},"hover_glyph":null,"muted_glyph":null,"name":"foo","nonselection_glyph":{"id":"439aa443-83e4-4cdb-8543-c4687ed3c772","type":"Line"},"selection_glyph":null},"id":"95d9077d-ad68-4df5-80dc-1e1d5ca44305","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"b48c53f7-fd91-4cf8-a599-505725a0cbfb","type":"BoxAnnotation"},"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"}},"id":"46a4d405-23b8-48fb-83a4-cfde1a3a374d","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"439aa443-83e4-4cdb-854 ...

# %%
interact(update_wav,k=(0,3*t_len-1))
# Out:
# <function __main__.update_wav>

# %% [markdown]
# # Summary
#
# Here are all the animated waves, put together with controls for a convenient demo.

# %%
interact(update_exp,k=IntSlider(min=0,max=t_len-1,description='Finite Diff, Explicit, init position'))
interact(update_expD,k=IntSlider(min=0,max=3*t_len-1,description='Finite Diff, Explicit, init velocity'))
interact(update_imp,k=IntSlider(min=0,max=t_len-1,description='Finite Diff, Implicit, init position'))
interact(update_impD,k=IntSlider(min=0,max=3*t_len-1,description='Finite Diff, Implicit, init velocity'))
interact(update_dal,k=IntSlider(min=0,max=t_len-1,description="d'Alembert, init position"))
interact(update_dalD,k=IntSlider(min=0,max=3*t_len-1,description="d'Alembert, init velocity"))
interact(update_comp,k=IntSlider(min=0,max=t_len-1,description='Comparison, exact minus F.D.'))
interact(update_wav,k=IntSlider(min=0,max=3*t_len-1,description='Moving wave (exact)'))
# Out:
# <function __main__.update_wav>

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8e27026e-b573-432e-baf1-0db8a2d5f2a0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8e27026e-b573-432e-baf1-0db8a2d5f2a0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8e27026e-b573-432e-baf1-0db8a2d5f2a0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8e27026e-b573-432e-baf1-0db8a2d5f2a0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e80ace3a-79e2-418f-acd7-28fb758a2a01":{"roots":{"references":[{"attributes":{"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"},"ticker":{"id":"dba42c0e-0a9f-4224-8b03-42f4b9622c9a","type":"BasicTicker"}},"id":"68c82762-f047-4929-9302-2d47ea86dcee","type":"Grid"},{"attributes":{"formatter":{"id":"fe06140b-74dc-48a2-a40a-dc015a428866","type":"BasicTickFormatter"},"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"},"ticker":{"id":"d188b7e7-4e67-41fd-bcae-397dfea85af9","type":"BasicTicker"}},"id":"051e69ec-7de6-47e5-b00a-8f63760684c9","type":"LinearAxis"},{"attributes":{"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"}},"id":"545911ad-145d-44fa-89d6-cd9dbf6c449c","type":"SaveTool"},{"attributes":{"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"}},"id":"fd0f2d0d-a7b9-4ea0-8ad9-ebaabef2bf77","type":"ResetTool"},{"attributes":{"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"}},"id":"67707b69-1a8e-47e6-b24d-0f8f827f1aea","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"},"ticker":{"id":"d188b7e7-4e67-41fd-bcae-397dfea85af9","type":"BasicTicker"}},"id":"e1efa689-6e7e-4adc-ba38-4d05b923523c","type":"Grid"},{"attributes":{"callback":null},"id":"520102f6-d35f-47a0-9be6-4f4d83c6f610","type":"DataRange1d"},{"attributes":{},"id":"fe06140b-74dc-48a2-a40a-dc015a428866","type":"BasicTickFormatter"},{"attributes":{},"id":"dba42c0e-0a9f-4224-8b03-42f4b9622c9a","type":"BasicTicker"},{"attributes":{"formatter":{"id":"0b03b6a6-b7f6-4298-b3d9-5fc3fb42243f","type":"BasicTickFormatter"},"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"},"ticker":{"id":"dba42c0e-0a9f-4224-8b03-42f4b9622c9a","type":"BasicTicker"}},"id":"572b9c96-155c-4bee-aa2e-8f42d1c3871a","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9606e122-cd89-4179-a745-158d0868a4ea","type":"PanTool"},{"id":"f3d91650-566e-4c44-8f36-edf22b9d851c","type":"WheelZoomTool"},{"id":"46a4d405-23b8-48fb-83a4-cfde1a3a374d","type":"BoxZoomTool"},{"id":"545911ad-145d-44fa-89d6-cd9dbf6c449c","type":"SaveTool"},{"id":"fd0f2d0d-a7b9-4ea0-8ad9-ebaabef2bf77","type":"ResetTool"},{"id":"67707b69-1a8e-47e6-b24d-0f8f827f1aea","type":"HelpTool"}]},"id":"4f8c7a4c-360b-467e-9282-dc4bc2b76c3f","type":"Toolbar"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7899b394-ffeb-4b5d-b0ff-ff0472ff33d9","type":"Line"},{"attributes":{},"id":"0b03b6a6-b7f6-4298-b3d9-5fc3fb42243f","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b48c53f7-fd91-4cf8-a599-505725a0cbfb","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"e38a120a-7809-42a1-96c3-2d19515ca94e","type":"ColumnDataSource"},"glyph":{"id":"7899b394-ffeb-4b5d-b0ff-ff0472ff33d9","type":"Line"},"hover_glyph":null,"muted_glyph":null,"name":"foo","nonselection_glyph":{"id":"439aa443-83e4-4cdb-8543-c4687ed3c772","type":"Line"},"selection_glyph":null},"id":"95d9077d-ad68-4df5-80dc-1e1d5ca44305","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"b48c53f7-fd91-4cf8-a599-505725a0cbfb","type":"BoxAnnotation"},"plot":{"id":"719587f9-9805-4874-8407-978d5e010dd5","subtype":"Figure","type":"Plot"}},"id":"46a4d405-23b8-48fb-83a4-cfde1a3a374d","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"439aa443-83e4-4cdb-854 ...
